# %%
langs_str \
    = 'af,ar,az,bn,cs,de,en,es,et,fa,fi,fr,gl,gu,he,hi,hr,id,it,ja,ka,kk,km,ko,lt,lv,mk,ml,mn,mr,my,ne,nl,pl,ps,pt,ro,ru,si,sl,sv,sw,ta,te,th,tl,tr,uk,ur,vi,xh,zh'

# %%
langs = langs_str.split(',')

# %%
import lang2vec.lang2vec as l2v
import numpy as np
from tqdm import tqdm

# %%
letter_codes = list(map(lambda lang: l2v.LETTER_CODES[lang], langs))

# %%
for letter_code in letter_codes:
    print(letter_code)
# Out:
# afr
# ara
# aze
# ben
# ces
# deu
# eng
# spa
# est
# fas
# fin
# fra
# glg
# guj
# heb
# hin
# hrv
# ind
# ita
# jpn
# kat
# kaz
# khm
# kor
# lit
# lav
# mkd
# mal
# mon
# mar
# mya
# nep
# nld
# pol
# pus
# por
# ron
# rus
# sin
# slv
# swe
# swa
# tam
# tel
# tha
# tgl
# tur
# ukr
# urd
# vie
# xho
# zho

# %% [markdown]
# ### Find Language Families

# %%
for letter_code in letter_codes:
    features = l2v.get_features(letter_code, "fam", header=True)
    families_and_subfamilies = np.array(features['CODE'])[np.array(features[letter_code]) == 1]
    family = families_and_subfamilies[0]
    subfamily = ''
    others = []
    if len(families_and_subfamilies) > 1:
        subfamily = families_and_subfamilies[1]
    if len(families_and_subfamilies) > 2:
        others = families_and_subfamilies[2:]
    joined = ' / '.join(others)
    print(f'{family}\t{subfamily}\t{joined}')
# Out:
# F_Indo-European	F_Germanic	F_Northwest_Germanic / F_West_Germanic / F_Franconian / F_Low_Franconian / F_Afrikaansic
# F_Afro-Asiatic	F_Semitic	F_West_Semitic / F_Central_Semitic / F_Arabian
# F_Turkic	F_Common_Turkic	F_Oghuz-Kipchak-Uyghur
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Indo-Aryan_Eastern_zone / F_Oriya-Gauda-Kamrupa / F_Gauda-Kamrupa / F_Gauda-Banga
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_West_Slavic / F_Czech-Slovak / F_Czech-Lach
# F_Indo-European	F_Germanic	F_Northwest_Germanic / F_West_Germanic / F_Franconian / F_High_Franconian
# F_Indo-European	F_Germanic	F_Northwest_Germanic / F_West_Germanic / F_North_Sea_Germanic / F_Anglo-Frisian / F_Anglian / F_Mercian / F_Macro-English
# F_Indo-European	F_Italic	F_Latino-Faliscan / F_Latinic / F_Imperial_Latin / F_Romance / F_Italo-Western_Romance / F_Western_Romance / F_Shifted_Western_Romance / F_Southwestern_Shifted_Romance / F_West_Ibero-Romance / F_Castilic
# F_Uralic	F_Finnic
# F_Indo-European	F_Indo-Iranian	F_Iranian / F_Western_Iranian / F_Southwestern_Iranian / F_Farsic-Caucasian_Tat
# F_Uralic	F_Finnic	F_Nuclear_Finnish
# F_Indo-European	F_Italic	F_Latino-Faliscan / F_Latinic / F_Imperial_Latin / F_Romance / F_Italo-Western_Romance / F_Western_Romance / F_Shifted_Western_Romance / F_Northwestern_Shifted_Romance / F_Gallo-Rhaetian / F_Oil
# F_Indo-European	F_Italic	F_Latino-Faliscan / F_Latinic / F_Imperial_Latin / F_Romance / F_Italo-Western_Romance / F_Western_Romance / F_Shifted_Western_Romance / F_Southwestern_Shifted_Romance / F_West_Ibero-Romance
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Indo-Aryan_Central_zone / F_Subcontinental_Central_Indo-Aryan / F_Gujarati-Rajasthani / F_Gujaratic
# F_Afro-Asiatic	F_Semitic	F_West_Semitic / F_Central_Semitic / F_Northwest_Semitic / F_Canaanite / F_Hebrewic
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Indo-Aryan_Central_zone / F_Subcontinental_Central_Indo-Aryan / F_Western_Hindi / F_Hindustani
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_South_Slavic / F_Western_South_Slavic / F_Molise-SKB / F_South-Western_Slavic
# F_Austronesian	F_Nuclear_Austronesian	F_Malayo-Polynesian / F_Malayo-Sumbawan / F_North_and_East_Malayo-Sumbawan / F_Malayic / F_Nuclear_Malayic / F_Indonesian_Archipelago_Malay
# F_Indo-European	F_Italic	F_Latino-Faliscan / F_Latinic / F_Imperial_Latin / F_Romance / F_Italo-Western_Romance / F_Italo-Dalmatian / F_Italian_Romance
# F_Japonic	F_Japanese	F_Japan-Taiwan_Japanese
# F_Kartvelian	F_Georgian-Zan	F_Georgic
# F_Turkic	F_Common_Turkic	F_Oghuz-Kipchak-Uyghur / F_Oghuz / F_Kipchak / F_South_Kipchak
# F_Austroasiatic	F_Khmeric
# F_Koreanic
# F_Indo-European	F_Balto-Slavic	F_Eastern_Baltic
# F_Indo-European	F_Balto-Slavic	F_Eastern_Baltic
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_South_Slavic / F_Eastern_South_Slavic / F_Macedo-Bulgarian
# F_Dravidian	F_South_Dravidian	F_South_Dravidian_I / F_Tamil-Kannada / F_Tamil-Kota / F_Tamil-Toda / F_Tamil-Irula / F_Tamil-Kodagu / F_Tamil-Malayalam / F_Malayalamoid
# F_Mongolic	F_Eastern_Mongolic	F_Oirat-Khalkha / F_Khalkha-Buriat
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Indo-Aryan_Southern_zone / F_Maharastric / F_Marathic
# F_Sino-Tibetan	F_Burmo-Qiangic	F_Lolo-Burmese / F_Burmish / F_Southern_Burmish / F_Nuclear_Southern_Burmish / F_Old-Modern_Burmese
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Indo-Aryan_Northern_zone
# F_Indo-European	F_Germanic	F_Northwest_Germanic / F_West_Germanic / F_Franconian / F_Low_Franconian / F_Macro-Dutch / F_Middle-Modern_Dutch / F_Modern_Dutch
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_West_Slavic / F_Lechitic
# F_Indo-European	F_Indo-Iranian	F_Iranian / F_Eastern_Iranian / F_Southeastern_Iranian / F_Pashto
# F_Indo-European	F_Italic	F_Latino-Faliscan / F_Latinic / F_Imperial_Latin / F_Romance / F_Italo-Western_Romance / F_Western_Romance / F_Shifted_Western_Romance / F_Southwestern_Shifted_Romance / F_West_Ibero-Romance
# F_Indo-European	F_Italic	F_Latino-Faliscan / F_Latinic / F_Imperial_Latin / F_Romance / F_Eastern_Romance / F_Macro-Romanian
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_East_Slavic
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Sinhalese-Maldivian / F_Sinhalaic
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_South_Slavic / F_Western_South_Slavic
# F_Indo-European	F_Germanic	F_Northwest_Germanic / F_North_Germanic / F_East_Scandinavian / F_Macro-Swedish
# F_Atlantic-Congo	F_Volta-Congo	F_Benue-Congo / F_Bantoid / F_Southern_Bantoid / F_Narrow_Bantu / F_East_Bantu / F_Northeast_Savanna_Bantu / F_Northeast_Coastal_Bantu / F_Coastal_NEC_Bantu / F_Sabaki-Swahili
# F_Dravidian	F_South_Dravidian	F_South_Dravidian_I / F_Tamil-Kannada / F_Tamil-Kota / F_Tamil-Toda / F_Tamil-Irula / F_Tamil-Kodagu / F_Tamil-Malayalam / F_Tamiloid
# F_Dravidian	F_Central_Dravidian	F_Teluguic
# F_Tai-Kadai	F_Kam-Tai	F_Be-Tai / F_Daic / F_Central-Southwestern_Tai / F_Wenma-Southwestern_Tai / F_Sapa-Southwestern_Tai / F_Southwestern_Tai / F_Sputhwestern_Thai_PH / F_Lao-Thai
# F_Austronesian	F_Nuclear_Austronesian	F_Malayo-Polynesian / F_Greater_Central_Philippine / F_Central_Philippine / F_Tagalogic / F_Tagalog-Filipino
# F_Turkic	F_Common_Turkic	F_Oghuz-Kipchak-Uyghur / F_Oghuz / F_West_Oghuz / F_Nuclear_West_Oghuz
# F_Indo-European	F_Balto-Slavic	F_Slavic / F_East_Slavic / F_Ukrainian-Rusyn
# F_Indo-European	F_Indo-Iranian	F_Indo-Aryan / F_Indo-Aryan_Central_zone / F_Subcontinental_Central_Indo-Aryan / F_Western_Hindi / F_Hindustani
# F_Austroasiatic	F_Vietic	F_Viet-Muong
# F_Atlantic-Congo	F_Volta-Congo	F_Benue-Congo / F_Bantoid / F_Southern_Bantoid / F_Narrow_Bantu / F_East_Bantu / F_Southern_Bantu-Makua / F_Nguni-Tsonga / F_Nguni_(S.40) / F_Zulu-Xhosa
# F_Sino-Tibetan

# %% [markdown]
# ### Find Syntax WALS

# %%
for letter_code in letter_codes:
    features = l2v.get_features(letter_code, "syntax_wals", header=True)
    for k, v in features.items():
        features[k] = v[:5]
    feature_map = np.array(list(map(lambda x: x if x != '--' else 0, features[letter_code]))) == 1
    syntax = np.array(features['CODE'])[feature_map == 1]
    print(syntax)
# Out:
# []
# ['S_SVO' 'S_VSO']
# ['S_SOV']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO' 'S_SOV']
# ['S_SVO']
# ['S_SVO']
# ['S_SVO']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO']
# []
# ['S_SOV']
# ['S_SVO']
# ['S_SOV']
# []
# ['S_SVO']
# ['S_SVO']
# ['S_SOV']
# ['S_SOV']
# []
# ['S_SVO']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO']
# ['S_SVO']
# ['S_SOV']
# ['S_SOV']
# ['S_SOV']
# ['S_SOV']
# ['S_SOV']
# ['S_SVO' 'S_SOV']
# ['S_SVO']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO']
# ['S_SVO']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO']
# ['S_SVO']
# ['S_SOV']
# ['S_SOV']
# ['S_SVO']
# ['S_VSO']
# ['S_SOV']
# ['S_SVO']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO']
# ['S_SVO']

# %% [markdown]
# ### Find Syntax SSWL

# %%
for letter_code in letter_codes:
    features = l2v.get_features(letter_code, "syntax_sswl", header=True)
    for k, v in features.items():
        features[k] = v[:5]
    feature_map = np.array(list(map(lambda x: x if x != '--' else 0, features[letter_code]))) == 1
    syntax = np.array(features['CODE'])[feature_map == 1]
    print(syntax)
# Out:
# ['S_SVO' 'S_SOV']
# ['S_SVO' 'S_VSO' 'S_VOS' 'S_OVS']
# []
# ['S_SOV']
# ['S_SVO' 'S_OVS']
# ['S_SVO' 'S_SOV']
# ['S_SVO']
# ['S_SVO']
# []
# []
# ['S_SVO']
# ['S_SVO']
# ['S_SVO' 'S_VSO' 'S_VOS' 'S_OVS']
# []
# ['S_SVO']
# ['S_SOV']
# []
# ['S_SVO']
# ['S_SVO' 'S_SOV' 'S_VOS']
# ['S_SOV']
# ['S_SVO' 'S_SOV' 'S_VSO' 'S_VOS' 'S_OVS']
# []
# []
# ['S_SOV']
# ['S_SVO' 'S_SOV' 'S_VSO' 'S_OVS']
# []
# []
# ['S_SOV']
# []
# []
# ['S_SOV']
# ['S_SOV']
# ['S_SVO' 'S_SOV']
# ['S_SVO' 'S_SOV' 'S_OVS']
# ['S_SOV']
# ['S_SVO']
# ['S_SVO' 'S_VSO' 'S_VOS']
# ['S_SVO']
# []
# ['S_SVO']
# ['S_SVO']
# ['S_SVO']
# []
# []
# ['S_SVO']
# ['S_VSO' 'S_VOS']
# ['S_SVO' 'S_SOV' 'S_VSO' 'S_VOS' 'S_OVS']
# ['S_SVO']
# []
# ['S_SVO']
# []
# ['S_SVO' 'S_SOV']

# %% [markdown]
# ### SVO with WALS fallback to SSWL if empty

# %%
svo_orders = []
for letter_code in letter_codes:
    features = l2v.get_features(letter_code, "syntax_wals", header=True)
    for k, v in features.items():
        features[k] = v[:5]
    features_sswl = l2v.get_features(letter_code, "syntax_sswl", header=True)
    for k, v in features_sswl.items():
        features_sswl[k] = v[:5]
    feature_map = np.array(list(map(lambda x: x if x != '--' else 0, features[letter_code]))) == 1
    feature_map_sswl = np.array(list(map(lambda x: x if x != '--' else 0, features_sswl[letter_code]))) == 1
    syntax = np.array(features['CODE'])[feature_map == 1]
    if len(syntax) == 0:
        syntax = np.array(features_sswl['CODE'])[feature_map_sswl == 1]
    svo_orders.append('/'.join(syntax))

# %%
for svo_order in svo_orders:
    print(svo_order)
# Out:
# S_SVO/S_SOV
# S_SVO/S_VSO
# S_SOV
# S_SOV
# S_SVO
# S_SVO/S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO/S_VSO/S_VOS/S_OVS
# S_SOV
# S_SVO
# S_SOV
#
# S_SVO
# S_SVO
# S_SOV
# S_SOV
#
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SOV
# S_SOV
# S_SOV
# S_SOV
# S_SVO/S_SOV
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SOV
# S_SVO
# S_VSO
# S_SOV
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO

# %%
svo_orders = []
for letter_code in letter_codes:
    features = l2v.get_features(letter_code, "syntax_knn", header=True)
    for k, v in features.items():
        features[k] = v[:5]
    feature_map = np.array(list(map(lambda x: x if x != '--' else 0, features[letter_code]))) == 1
    syntax = np.array(features['CODE'])[feature_map == 1]
    svo_orders.append('/'.join(syntax))
for svo_order in svo_orders:
    print(svo_order)
# Out:
# S_SVO/S_SOV
# S_SVO/S_VSO
# S_SOV
# S_SOV
# S_SVO
# S_SVO/S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO/S_VSO/S_VOS/S_OVS
# S_SOV
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SVO/S_SOV
# S_SOV
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SOV
# S_SOV
# S_SOV
# S_SOV
# S_SVO/S_SOV
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO
# S_SOV
# S_SOV
# S_SVO
# S_VSO
# S_SOV
# S_SVO
# S_SOV
# S_SVO
# S_SVO
# S_SVO

# %% [markdown]
# ### GEO - feature Clustering

# %%
geo_features = {}
for letter_code in tqdm(letter_codes):
    features = l2v.get_features(letter_code, "geo", header=False)
    geo_features[letter_code] = features[letter_code]
# Out:
# 100%|██████████| 52/52 [00:03<00:00, 16.17it/s]

# %% [markdown]
# ### Overall Typology Clustering

# %%
synt_phono_inventory_features = dict()
feature_set = "syntax_knn+phonology_knn+inventory_knn"
for letter_code in letter_codes:
    feat = l2v.get_features(letter_code, feature_set)[letter_code]
    synt_phono_inventory_features[letter_code] = np.asarray(feat)

# %%
synt_phono_inventory_features.keys()
# Out:
# dict_keys(['afr', 'ara', 'aze', 'ben', 'ces', 'deu', 'eng', 'spa', 'est', 'fas', 'fin', 'fra', 'glg', 'guj', 'heb', 'hin', 'hrv', 'ind', 'ita', 'jpn', 'kat', 'kaz', 'khm', 'kor', 'lit', 'lav', 'mkd', 'mal', 'mon', 'mar', 'mya', 'nep', 'nld', 'pol', 'pus', 'por', 'ron', 'rus', 'sin', 'slv', 'swe', 'swa', 'tam', 'tel', 'tha', 'tgl', 'tur', 'ukr', 'urd', 'vie', 'xho', 'zho'])

# %% [markdown]
# ### Learned Features

# %%
synt_phono_inventory_features = dict()
feature_set = "learned"
for letter_code in letter_codes:
    feat = l2v.get_features(letter_code, feature_set)[letter_code]
    synt_phono_inventory_features[letter_code] = np.asarray(feat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 4
#       2 feature_set = "learned"
#       3 for letter_code in letter_codes:
# ----> 4     feat = l2v.get_features(letter_code, feature_set)[letter_code]
#       5     synt_phono_inventory_features[letter_code] = np.asarray(feat)
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/lang2vec/lang2vec.py:316, in get_features(languages, feature_set_inp, header, minimal)
#     313 else:
#     314     raise Exception("Improper type "+type(languages)+" for languages.\nRequires string or list of strings.")
# --> 316 feature_names, feature_values = get_concatenated_sets(lang_codes, feature_set_inp)
#     317 feature_names = np.array([ f.replace(" ","_") for f in feature_names ])
#     319 if minimal:
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/lang2vec/lang2vec.py:222, in get_concatenated_sets(lang_codes, feature_set_str)
#     220 feature_values = np.ndarray((len(lang_codes),0))
#     221 for feature_set_part in feature_set_parts:
# --> 222     more_feature_names, more_feature_values = get_union_sets(lang_codes, feature_set_part)
#     223     feature_names += more_feature_names
#     224     feature_values = np.concatenate([feature_values, more_feature_values], axis=1)
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/lang2vec/lang2vec.py:202, in get_union_sets(lang_codes, feature_set_str)
#     200 else:
#     201     raise Exception("Improper type "+type(feature_set_str)+" for feature_set.\nRequires string or list of strings.")
# --> 202 feature_names, feature_values = get_named_set(lang_codes, feature_set_parts[0])
#     203 for feature_set_part in feature_set_parts[1:]:
#     204     more_feature_names, more_feature_values = get_named_set(lang_codes, feature_set_part)
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/lang2vec/lang2vec.py:172, in get_named_set(lang_codes, feature_set)
#     170     return get_id_set(lang_codes)
#     171 if feature_set == "learned":
# --> 172     return get_learned_set(lang_codes)
#     174 if feature_set not in FEATURE_SETS_DICT:
#     175     raise Exception("ERROR: Invalid feature set " + feature_set +
#     176         ". You can run lang2vec.FEATURE_SETS or " +
#     177         " lang2vec.available_feature_sets() to see the available feature sets.")
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/lang2vec/lang2vec.py:157, in get_learned_set(lang_codes)
#     155 filename = "learned.npy"
#     156 filename = pkg_resources.resource_filename(__name__, os.path.join('data', filename))
# --> 157 feature_database = np.load(filename, encoding="latin1").item()
#     158 lang_codes = [ get_learned_language_code(l, feature_database) for l in lang_codes ]
#     159 feature_names = [ "LEARNED_%03d" % i for i in range(512) ]
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/numpy/lib/npyio.py:456, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453         return format.open_memmap(file, mode=mmap_mode,
#     454                                   max_header_size=max_header_size)
#     455     else:
# --> 456         return format.read_array(fid, allow_pickle=allow_pickle,
#     457                                  pickle_kwargs=pickle_kwargs,
#     458                                  max_header_size=max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
#
# File ~/anaconda3/envs/lit-gpt/lib/python3.10/site-packages/numpy/lib/format.py:795, in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     792 if dtype.hasobject:
#     793     # The array contained Python objects. We need to unpickle the data.
#     794     if not allow_pickle:
# --> 795         raise ValueError("Object arrays cannot be loaded when "
#     796                          "allow_pickle=False")
#     797     if pickle_kwargs is None:
#     798         pickle_kwargs = {}
#
# ValueError: Object arrays cannot be loaded when allow_pickle=False

# %% [markdown]
# # Language x (Task + Model + Subset) Matrix

# %%
import pandas as pd
from itertools import chain

# Define language presence in each task, model, and subset
task_languages = {
    'xnli': ['ar', 'hi', 'es', 'ru', 'sw', 'tr', 'bg', 'de', 'el', 'en', 'fr', 'th', 'ur', 'vi', 'zh'],
    'xcopa': ['tr', 'sw', 'et', 'id', 'it', 'ta', 'th', 'vi', 'ht', 'qu', 'zh'],
    'xstorycloze': ['ar', 'es', 'hi', 'ru', 'sw', 'en', 'eu', 'id', 'my', 'te', 'zh'],
    'xwinograd': ['ja', 'ru', 'en', 'fr', 'pt', 'zh'],
    'pawsx': ['es', 'ja', 'ko', 'de', 'en', 'fr', 'zh']
}

model_languages = {
    'bloom': ['ak', 'ar', 'as', 'bm', 'eu', 'bn', 'ca', 'ny', 'sn', 'tum', 'en', 'fon', 'fr', 'gu', 'hi', 'ig',
              'id', 'xh', 'zu', 'kn', 'ki', 'rw', 'rn', 'ln', 'lg', 'ml', 'mr', 'ne', 'nso', 'or', 'pt', 'pa', 'st',
              'tn', 'zhs', 'es', 'sw', 'ta', 'te', 'zht', 'tw', 'ur', 'vi', 'wo', 'ts', 'yo'],
    'mgpt': ['ar', 'he', 'vi', 'id', 'jv', 'ms', 'tl', 'lv', 'lt', 'eu', 'ml', 'ta', 'te', 'hy', 'bn', 'mr', 'hi',
             'ur', 'af', 'da', 'en', 'de', 'sv', 'fr', 'it', 'pt', 'ro', 'es', 'el', 'os', 'tg', 'fa', 'ja', 'ka',
             'ko', 'th', 'bxr', 'xal', 'mn', 'sw', 'yo', 'be', 'bg', 'ru', 'uk', 'pl', 'my', 'uz', 'ba', 'kk', 'ky',
             'tt', 'az', 'cv', 'tr', 'tk', 'tyv', 'sax', 'et', 'fi', 'hu'],
    'mt5': ['af', 'sq', 'am', 'ar', 'hy', 'az', 'eu', 'be', 'bn', 'bg', 'my', 'ca', 'ceb', 'ny', 'zh', 'co', 'cs',
            'da', 'nl', 'en', 'eo', 'et', 'fil', 'fi', 'fr', 'gl', 'ka', 'de', 'el', 'gu', 'ht', 'ha', 'haw', 'he',
            'hi', 'hmn', 'hu', 'is', 'ig', 'id', 'ga', 'it', 'ja', 'jv', 'kn', 'kk', 'km', 'ko', 'ku', 'ky', 'lo',
            'la', 'lv', 'lt', 'lb', 'mk', 'mg', 'ms', 'ml', 'mt', 'mi', 'mr', 'mn', 'ne', 'no', 'ps', 'fa', 'pl',
            'pt', 'pa', 'ro', 'ru', 'sm', 'gd', 'sr', 'sn', 'sd', 'si', 'sk', 'sl', 'so', 'st', 'es', 'su', 'sw',
            'sv', 'tg', 'ta', 'te', 'th', 'tr', 'uk', 'ur', 'uz', 'vi', 'cy', 'fy', 'xh', 'yi', 'yo', 'zu']
}

# Define subset languages
subsets = {
    'RND-1': ['cs', 'gu', 'hi', 'id', 'ko', 'lv', 'mk', 'ml', 'ps', 'pt', 'si', 'ta', 'vi', 'zh'],
    'RND-2': ['cs', 'en', 'et', 'fr', 'hi', 'hr', 'it', 'ja', 'ml', 'mn', 'mr', 'ne', 'pl', 'pt'],
    'RND-3': ['ar', 'az', 'de', 'en', 'es', 'et', 'he', 'hi', 'id', 'ml', 'ps', 'ru', 'sv', 'uk'],
    'FAM-1': ['az', 'en', 'fi', 'he', 'ja', 'ka', 'vi', 'ko', 'ml', 'mn', 'my', 'th', 'tl', 'xh'],
    'FAM-2': ['ar', 'en', 'fi', 'id', 'ja', 'ka', 'ko', 'mn', 'sw', 'ta', 'th', 'tr', 'vi', 'zh'],
    'FAM-3': ['af', 'az', 'et', 'he', 'ja', 'ka', 'ko', 'ml', 'mn', 'my', 'th', 'tl', 'vi', 'xh'],
    'GEO-1': ['af', 'bn', 'et', 'fr', 'gu', 'he', 'hr', 'id', 'ja', 'kk', 'mn', 'sw', 'ta', 'vi'],
    'GEO-2': ['af', 'bn', 'et', 'fr', 'he', 'hr', 'id', 'ja', 'ka', 'kk', 'mn', 'ta', 'ur', 'vi'],
    'GEO-3': ['af', 'bn', 'et', 'fr', 'he', 'hr', 'id', 'ja', 'kk', 'mn', 'sw', 'ta', 'ur', 'vi'],
    'LEARN-1': ['cs', 'hi', 'id', 'km', 'ko', 'lt', 'lv', 'my', 'nl', 'pt', 'sl', 'ta', 'tl', 'vi'],
    'LEARN-2': ['cs', 'fi', 'hr', 'km', 'ko', 'lt', 'lv', 'my', 'nl', 'pt', 'sl', 'ta', 'uk', 'vi'],
    'LEARN-3': ['cs', 'hi', 'id', 'ja', 'lt', 'lv', 'nl', 'pt', 'sl', 'sv', 'ta', 'tl', 'tr', 'vi'],
    'SEM-1': ['gl', 'gu', 'ka', 'kk', 'ko', 'ml', 'pl', 'ps', 'si', 'sl', 'sv', 'tl', 'uk', 'vi'],
    'SEM-2': ['en', 'fr', 'gl', 'gu', 'ka', 'kk', 'ko', 'pl', 'ps', 'sl', 'sv', 'tl', 'uk', 'vi'],
    'SEM-3': ['en', 'gl', 'gu', 'ka', 'kk', 'ko', 'pl', 'ps', 'sl', 'sv', 'tl', 'uk', 'vi'],
    'TYPO-1': ['az', 'bn', 'de', 'et', 'fa', 'hi', 'it', 'ja', 'mk', 'sw', 'ta', 'tl', 'vi', 'zh'],
    'TYPO-2': ['ar', 'az', 'bn', 'de', 'et', 'fa', 'it', 'ja', 'mk', 'sw', 'ta', 'th', 'ur', 'zh'],
    'TYPO-3': ['ar', 'az', 'bn', 'en', 'fi', 'he', 'hi', 'it', 'ja', 'mk', 'nl', 'sw', 'ta', 'th'],
    'ALL': ['af', 'ar', 'az', 'bn', 'cs', 'de', 'en', 'es', 'et', 'fa', 'fi', 'fr', 'gl', 'gu', 'he', 'hi', 'hr', 'id',
            'it', 'ja', 'ka', 'kk', 'km', 'ko', 'lt', 'lv', 'mk', 'ml', 'mn', 'mr', 'my', 'ne', 'nl', 'pl', 'ps', 'pt',
            'ro', 'ru', 'si', 'sl', 'sv', 'sw', 'ta', 'te', 'th', 'tl', 'tr', 'uk', 'ur', 'vi', 'xh', 'zh']
}

# Define all unique languages across tasks, models, and subsets
all_languages = [*list(task_languages.values()), *list(model_languages.values()), *list(subsets.values())]
all_languages = set(chain.from_iterable(all_languages))

# %%
# Create a DataFrame with languages as rows and tasks, models, and subsets as columns
columns = ['xnli', 'xcopa', 'xstorycloze', 'xwinograd', 'pawsx', 'bloom', 'mgpt', 'mt5'] + list(subsets.keys())
df = pd.DataFrame(0, index=sorted(all_languages), columns=columns)

# %%
# Mark presence of each language in tasks
for task, langs in task_languages.items():
    df.loc[langs, task] = 1

# Mark presence of each language in models
for model, langs in model_languages.items():
    df.loc[langs, model] = 1

# Mark presence of each language in subsets
for subset, langs in subsets.items():
    df.loc[langs, subset] = 1

# %%
df.to_csv('language_matrix.csv')

# %% [markdown]
# #### TASK SPECIFIC

# %%
from collections import defaultdict

# Group subsets together
subset_groups = {
    'RND': ['RND-1', 'RND-2', 'RND-3'],
    'FAM': ['FAM-1', 'FAM-2', 'FAM-3'],
    'GEO': ['GEO-1', 'GEO-2', 'GEO-3'],
    'LEARN': ['LEARN-1', 'LEARN-2', 'LEARN-3'],
    'SEM': ['SEM-1', 'SEM-2', 'SEM-3'],
    'TYPO': ['TYPO-1', 'TYPO-2', 'TYPO-3'],
    'ALL': ['ALL']
}

# %%
def task_x_subsets(task_name: str, ):
    task_languages_set = set(task_languages[task_name])

    # Initialize dictionary to store intersection and difference counts
    group_results = defaultdict(lambda: {'intersection': set(), 'difference': set()})

    # Calculate intersections and differences for each group
    for group_name, subset_names in subset_groups.items():
        group_intersection = set()
        group_difference = set()

        # For each subset in the group, calculate intersection and difference
        for subset_name in subset_names:
            subset_languages_set = set(subsets[subset_name])
            group_intersection.update(task_languages_set.intersection(subset_languages_set))
            group_difference.update(subset_languages_set.difference(task_languages_set))

        # Store the results in the dictionary
        group_results[group_name]['intersection'] = group_intersection
        group_results[group_name]['difference'] = group_difference

    # Sort groups based on the number of intersections
    sorted_groups = sorted(group_results.items(), key=lambda x: len(x[1]['intersection']), reverse=True)

    # Display sorted results
    for group_name, result in sorted_groups:
        print(
            f"{group_name} -> {len(result['intersection'])} languages in common with {task_name.upper()}: {result['intersection']}")
        print(
            f"{group_name} -> {len(result['difference'])} languages not in {task_name.upper()}: {result['difference']}")

# %%
def task_x_models(task_name: str, ):
    """
    intersections of TASK (XNLI, XCOPA etc) and model languages
    :param task_name: 
    :return: 
    """
    task_languages_set = set(task_languages[task_name])

    # Intersections with each model's languages
    model_results = {}

    for model_name, model_languages_set in model_languages.items():
        model_languages_set = set(model_languages_set)
        intersection = task_languages_set.intersection(model_languages_set)
        differences = model_languages_set.difference(task_languages_set)

        model_results[model_name] = {
            'intersection': intersection,
            'difference': differences
        }

    # Sort models based on the number of intersections
    sorted_models = sorted(model_results.items(), key=lambda x: len(x[1]['intersection']), reverse=True)

    # Display sorted results
    for model_name, result in sorted_models:
        print(
            f"{model_name} -> {len(result['intersection'])} languages in common with  {task_name.upper()}: {result['intersection']}")
        print(
            f"{model_name} -> {len(result['difference'])} languages not in  {task_name.upper()}: {result['difference']}")

# %%
##### XNLI

task_x_subsets(task_name='xnli')
print('\n---------------------\n')
task_x_models(task_name='xnli')
# Out:
# ALL -> 13 languages in common with XNLI: {'ar', 'en', 'es', 'hi', 'ur', 'sw', 'tr', 'de', 'fr', 'ru', 'vi', 'zh', 'th'}
# ALL -> 39 languages not in XNLI: {'kk', 'et', 'he', 'pt', 'lt', 'mn', 'ml', 'nl', 'fi', 'gl', 'km', 'mr', 'ka', 'ko', 'az', 'af', 'ta', 'te', 'lv', 'sl', 'si', 'pl', 'mk', 'hr', 'cs', 'fa', 'bn', 'xh', 'ps', 'gu', 'ne', 'it', 'ja', 'my', 'ro', 'tl', 'id', 'uk', 'sv'}
# RND -> 9 languages in common with XNLI: {'ar', 'en', 'es', 'hi', 'fr', 'de', 'vi', 'ru', 'zh'}
# RND -> 23 languages not in XNLI: {'ta', 'et', 'he', 'pt', 'mn', 'lv', 'si', 'ml', 'pl', 'mk', 'uk', 'hr', 'ps', 'gu', 'ne', 'it', 'ja', 'mr', 'id', 'ko', 'az', 'cs', 'sv'}
# TYPO -> 9 languages in common with XNLI: {'ar', 'en', 'hi', 'ur', 'sw', 'de', 'vi', 'zh', 'th'}
# TYPO -> 12 languages not in XNLI: {'ta', 'et', 'he', 'fi', 'it', 'ja', 'tl', 'az', 'mk', 'nl', 'fa', 'bn'}
# FAM -> 7 languages in common with XNLI: {'ar', 'en', 'sw', 'tr', 'vi', 'zh', 'th'}
# FAM -> 15 languages not in XNLI: {'af', 'ta', 'et', 'he', 'mn', 'ml', 'xh', 'fi', 'my', 'ja', 'ka', 'tl', 'ko', 'id', 'az'}
# GEO -> 4 languages in common with XNLI: {'sw', 'fr', 'vi', 'ur'}
# GEO -> 12 languages not in XNLI: {'af', 'ta', 'et', 'he', 'kk', 'mn', 'hr', 'bn', 'gu', 'ja', 'ka', 'id'}
# LEARN -> 3 languages in common with XNLI: {'tr', 'vi', 'hi'}
# LEARN -> 17 languages not in XNLI: {'ta', 'pt', 'lt', 'lv', 'sl', 'uk', 'hr', 'nl', 'fi', 'km', 'my', 'ja', 'tl', 'id', 'ko', 'cs', 'sv'}
# SEM -> 3 languages in common with XNLI: {'fr', 'vi', 'en'}
# SEM -> 13 languages not in XNLI: {'kk', 'sl', 'si', 'ml', 'pl', 'ps', 'gu', 'gl', 'ka', 'tl', 'ko', 'uk', 'sv'}
#
# ---------------------
#
# mt5 -> 15 languages in common with  XNLI: {'el', 'ar', 'en', 'es', 'hi', 'ur', 'sw', 'tr', 'de', 'bg', 'fr', 'ru', 'vi', 'zh', 'th'}
# mt5 -> 86 languages not in  XNLI: {'be', 'kk', 'he', 'sm', 'mt', 'sq', 'mn', 'co', 'ml', 'tg', 'ga', 'yi', 'uz', 'ny', 'gl', 'km', 'mr', 'ka', 'ca', 'mg', 'da', 'ko', 'lb', 'te', 'lv', 'sl', 'si', 'mk', 'mi', 'bn', 'fa', 'ps', 'gu', 'ne', 'ceb', 'sr', 'ro', 'lo', 'id', 'cs', 'gd', 'sd', 'et', 'is', 'lt', 'pt', 'haw', 'nl', 'hy', 'fi', 'hmn', 'sk', 'pa', 'la', 'eu', 'am', 'fy', 'zu', 'st', 'az', 'hu', 'eo', 'kn', 'af', 'ta', 'ku', 'sn', 'su', 'jv', 'no', 'pl', 'ig', 'so', 'ms', 'yo', 'xh', 'ky', 'cy', 'ht', 'it', 'ja', 'my', 'ha', 'fil', 'uk', 'sv'}
# mgpt -> 14 languages in common with  XNLI: {'el', 'ar', 'en', 'es', 'hi', 'ur', 'sw', 'tr', 'de', 'bg', 'fr', 'ru', 'vi', 'th'}
# mgpt -> 47 languages not in  XNLI: {'bxr', 'kk', 'he', 'be', 'et', 'sv', 'lt', 'pt', 'cv', 'mn', 'ml', 'tg', 'hy', 'uz', 'fi', 'xal', 'tt', 'mr', 'eu', 'ka', 'tk', 'da', 'ko', 'az', 'hu', 'af', 'ta', 'ba', 'te', 'jv', 'lv', 'pl', 'ms', 'yo', 'fa', 'bn', 'ky', 'sax', 'it', 'ja', 'ro', 'my', 'tl', 'id', 'tyv', 'uk', 'os'}
# bloom -> 8 languages in common with  XNLI: {'ar', 'en', 'es', 'hi', 'ur', 'sw', 'fr', 'vi'}
# bloom -> 38 languages not in  XNLI: {'zht', 'pt', 'nso', 'zhs', 'or', 'ml', 'wo', 'ki', 'ny', 'pa', 'mr', 'eu', 'fon', 'ca', 'lg', 'tw', 'zu', 'st', 'ak', 'kn', 'ta', 'sn', 'te', 'bm', 'tn', 'ig', 'ts', 'rn', 'yo', 'bn', 'as', 'xh', 'rw', 'gu', 'ln', 'ne', 'tum', 'id'}

# %%
##### XCOPA

print('Intersections and Differences between XCOPA Languages and Subsets')
task_x_subsets(task_name='xcopa')
print('\n---------------------\n')
print('Intersections and Differences between XCOPA Languages and Models')
task_x_models(task_name='xcopa')
# Out:
# Intersections and Differences between XCOPA Languages and Subsets
# ALL -> 9 languages in common with XCOPA: {'ta', 'et', 'it', 'tr', 'sw', 'id', 'vi', 'zh', 'th'}
# ALL -> 43 languages not in XCOPA: {'kk', 'he', 'lt', 'pt', 'mn', 'hi', 'ml', 'ru', 'nl', 'fi', 'en', 'gl', 'km', 'mr', 'ka', 'ur', 'fr', 'de', 'ko', 'az', 'af', 'ar', 'te', 'lv', 'sl', 'si', 'pl', 'mk', 'hr', 'cs', 'fa', 'bn', 'xh', 'ps', 'gu', 'es', 'ne', 'my', 'ja', 'ro', 'tl', 'uk', 'sv'}
# FAM -> 8 languages in common with XCOPA: {'ta', 'et', 'tr', 'sw', 'id', 'vi', 'zh', 'th'}
# FAM -> 14 languages not in XCOPA: {'af', 'he', 'ar', 'mn', 'ml', 'xh', 'fi', 'en', 'my', 'ja', 'ka', 'tl', 'ko', 'az'}
# TYPO -> 7 languages in common with XCOPA: {'ta', 'et', 'it', 'sw', 'vi', 'zh', 'th'}
# TYPO -> 14 languages not in XCOPA: {'he', 'ar', 'hi', 'mk', 'nl', 'fa', 'bn', 'fi', 'en', 'ja', 'tl', 'ur', 'de', 'az'}
# RND -> 6 languages in common with XCOPA: {'ta', 'et', 'id', 'vi', 'it', 'zh'}
# RND -> 26 languages not in XCOPA: {'he', 'ar', 'pt', 'mn', 'lv', 'hi', 'si', 'ml', 'pl', 'ru', 'mk', 'uk', 'hr', 'ps', 'gu', 'en', 'es', 'ne', 'ja', 'mr', 'fr', 'de', 'ko', 'az', 'cs', 'sv'}
# GEO -> 5 languages in common with XCOPA: {'ta', 'et', 'sw', 'id', 'vi'}
# GEO -> 11 languages not in XCOPA: {'af', 'kk', 'he', 'mn', 'hr', 'bn', 'gu', 'ja', 'ka', 'ur', 'fr'}
# LEARN -> 4 languages in common with XCOPA: {'tr', 'ta', 'id', 'vi'}
# LEARN -> 16 languages not in XCOPA: {'pt', 'lt', 'lv', 'hi', 'sl', 'uk', 'hr', 'nl', 'fi', 'km', 'my', 'ja', 'tl', 'ko', 'cs', 'sv'}
# SEM -> 1 languages in common with XCOPA: {'vi'}
# SEM -> 15 languages not in XCOPA: {'kk', 'sl', 'si', 'ml', 'pl', 'ps', 'gu', 'gl', 'en', 'ka', 'tl', 'fr', 'ko', 'uk', 'sv'}
#
# ---------------------
#
# Intersections and Differences between XCOPA Languages and Models
# mt5 -> 10 languages in common with  XCOPA: {'ta', 'et', 'ht', 'it', 'tr', 'sw', 'id', 'vi', 'zh', 'th'}
# mt5 -> 91 languages not in  XCOPA: {'be', 'kk', 'he', 'sm', 'mt', 'sq', 'mn', 'co', 'hi', 'ml', 'tg', 'ga', 'yi', 'uz', 'ny', 'en', 'gl', 'km', 'mr', 'ka', 'ur', 'ca', 'de', 'mg', 'da', 'ko', 'ar', 'lb', 'te', 'lv', 'sl', 'si', 'bg', 'mk', 'mi', 'bn', 'fa', 'ps', 'gu', 'es', 'ne', 'ceb', 'sr', 'ro', 'lo', 'cs', 'gd', 'el', 'sd', 'is', 'lt', 'pt', 'ru', 'haw', 'nl', 'hy', 'fi', 'hmn', 'sk', 'pa', 'la', 'eu', 'am', 'fy', 'fr', 'zu', 'st', 'az', 'hu', 'eo', 'kn', 'af', 'ku', 'sn', 'su', 'jv', 'no', 'pl', 'ig', 'so', 'ms', 'yo', 'xh', 'ky', 'cy', 'ja', 'my', 'ha', 'fil', 'uk', 'sv'}
# mgpt -> 8 languages in common with  XCOPA: {'ta', 'et', 'it', 'tr', 'sw', 'id', 'vi', 'th'}
# mgpt -> 53 languages not in  XCOPA: {'bxr', 'el', 'he', 'be', 'kk', 'lt', 'pt', 'cv', 'mn', 'hi', 'ml', 'tg', 'ru', 'hy', 'uz', 'fi', 'xal', 'en', 'tt', 'mr', 'eu', 'ka', 'ur', 'fr', 'de', 'tk', 'da', 'ko', 'az', 'hu', 'af', 'ar', 'ba', 'te', 'jv', 'lv', 'pl', 'bg', 'ms', 'yo', 'fa', 'bn', 'ky', 'sax', 'es', 'ja', 'ro', 'my', 'tl', 'tyv', 'os', 'uk', 'sv'}
# bloom -> 4 languages in common with  XCOPA: {'sw', 'ta', 'id', 'vi'}
# bloom -> 42 languages not in  XCOPA: {'zht', 'pt', 'nso', 'zhs', 'hi', 'or', 'ml', 'wo', 'ki', 'ny', 'en', 'pa', 'mr', 'eu', 'fon', 'ca', 'lg', 'fr', 'tw', 'zu', 'ur', 'st', 'ak', 'kn', 'sn', 'ar', 'te', 'bm', 'tn', 'ig', 'ts', 'rn', 'yo', 'bn', 'as', 'xh', 'rw', 'gu', 'ln', 'ne', 'es', 'tum'}

# %%
# SUBSETS x MODELS

# Function to group subsets and calculate intersections with models
def collect_grouped_subset_model_intersections(model_languages, subset_groups):
    all_results = []

    # Iterate over all models and subset groups
    for model_name, model_languages_set in model_languages.items():
        model_languages_set = set(model_languages_set)

        for subset_group_name, subset_group in subset_groups.items():
            # Combine all subset languages in the group
            combined_subset_languages = set(chain.from_iterable(subset_group))

            # Calculate intersections and differences
            intersection = combined_subset_languages.intersection(model_languages_set)
            differences = combined_subset_languages.difference(model_languages_set)

            # Store results in a list
            all_results.append({
                'model': model_name,
                'subset_group': subset_group_name,
                'intersection': intersection,
                'difference': differences,
                'num_intersection': len(intersection)
            })

    # Sort the results by the number of intersections in descending order
    sorted_all_results = sorted(all_results, key=lambda x: x['num_intersection'], reverse=True)

    # Return sorted results
    return sorted_all_results


# Subset groups (e.g., group RND-1, RND-2, RND-3 into one RND group)
subset_groups = {
    'RND': [subsets['RND-1'], subsets['RND-2'], subsets['RND-3']],
    'FAM': [subsets['FAM-1'], subsets['FAM-2'], subsets['FAM-3']],
    'GEO': [subsets['GEO-1'], subsets['GEO-2'], subsets['GEO-3']],
    'LEARN': [subsets['LEARN-1'], subsets['LEARN-2'], subsets['LEARN-3']],
    'SEM': [subsets['SEM-1'], subsets['SEM-2'], subsets['SEM-3']],
    'TYPO': [subsets['TYPO-1'], subsets['TYPO-2'], subsets['TYPO-3']],
    'ALL': [subsets['ALL']]
}


# Display the sorted results
def display_sorted_grouped_results(sorted_results):
    for result in sorted_results:
        print(
            f"{result['subset_group']} with {result['model']} -> {result['num_intersection']} languages in common: {result['intersection']}")
        print(
            f"{result['subset_group']} with {result['model']} -> {len(result['difference'])} languages not in model: {result['difference']}")
        print()  # For better readability


# Example of how to use the function
sorted_grouped_results = collect_grouped_subset_model_intersections(model_languages, subset_groups)

# Display the results
display_sorted_grouped_results(sorted_grouped_results)
# Out:
# ALL with mt5 -> 50 languages in common: {'kk', 'et', 'he', 'pt', 'lt', 'mn', 'hi', 'ml', 'tr', 'ru', 'nl', 'fi', 'en', 'gl', 'km', 'mr', 'ka', 'ur', 'fr', 'de', 'ko', 'az', 'af', 'ta', 'ar', 'te', 'lv', 'sl', 'si', 'pl', 'mk', 'zh', 'cs', 'fa', 'bn', 'th', 'xh', 'ps', 'gu', 'es', 'ne', 'it', 'ja', 'my', 'ro', 'sw', 'id', 'vi', 'uk', 'sv'}
# ALL with mt5 -> 2 languages not in model: {'hr', 'tl'}
#
# ALL with mgpt -> 39 languages in common: {'kk', 'et', 'he', 'pt', 'lt', 'mn', 'hi', 'ml', 'tr', 'ru', 'fi', 'en', 'mr', 'ka', 'ur', 'fr', 'de', 'ko', 'az', 'af', 'ta', 'ar', 'te', 'lv', 'pl', 'fa', 'bn', 'th', 'es', 'it', 'ja', 'my', 'ro', 'tl', 'sw', 'id', 'vi', 'uk', 'sv'}
# ALL with mgpt -> 13 languages not in model: {'xh', 'ps', 'gu', 'gl', 'km', 'ne', 'sl', 'si', 'cs', 'mk', 'zh', 'hr', 'nl'}
#
# RND with mt5 -> 31 languages in common: {'et', 'he', 'pt', 'mn', 'hi', 'ml', 'ru', 'en', 'mr', 'fr', 'de', 'ko', 'az', 'ta', 'ar', 'lv', 'si', 'pl', 'mk', 'zh', 'cs', 'ps', 'gu', 'es', 'ne', 'it', 'ja', 'id', 'vi', 'uk', 'sv'}
# RND with mt5 -> 1 languages not in model: {'hr'}
#
# RND with mgpt -> 24 languages in common: {'et', 'he', 'pt', 'mn', 'hi', 'ml', 'ru', 'en', 'mr', 'fr', 'de', 'ko', 'az', 'ta', 'ar', 'lv', 'pl', 'es', 'it', 'ja', 'id', 'vi', 'uk', 'sv'}
# RND with mgpt -> 8 languages not in model: {'ps', 'gu', 'hr', 'ne', 'si', 'mk', 'zh', 'cs'}
#
# FAM with mt5 -> 21 languages in common: {'et', 'he', 'mn', 'ml', 'tr', 'fi', 'en', 'ka', 'ko', 'az', 'af', 'ta', 'ar', 'zh', 'th', 'xh', 'my', 'ja', 'sw', 'id', 'vi'}
# FAM with mt5 -> 1 languages not in model: {'tl'}
#
# FAM with mgpt -> 20 languages in common: {'et', 'he', 'mn', 'ml', 'tr', 'fi', 'en', 'ka', 'ko', 'az', 'af', 'ta', 'ar', 'th', 'my', 'ja', 'tl', 'sw', 'id', 'vi'}
# FAM with mgpt -> 2 languages not in model: {'xh', 'zh'}
#
# TYPO with mt5 -> 20 languages in common: {'et', 'he', 'hi', 'nl', 'fi', 'en', 'ur', 'de', 'az', 'ta', 'ar', 'mk', 'zh', 'fa', 'th', 'bn', 'it', 'ja', 'sw', 'vi'}
# TYPO with mt5 -> 1 languages not in model: {'tl'}
#
# ALL with bloom -> 18 languages in common: {'ta', 'xh', 'ar', 'en', 'pt', 'gu', 'te', 'ne', 'mr', 'hi', 'es', 'ur', 'ml', 'fr', 'sw', 'id', 'vi', 'bn'}
# ALL with bloom -> 34 languages not in model: {'kk', 'et', 'he', 'lt', 'mn', 'tr', 'ru', 'nl', 'fi', 'gl', 'km', 'ka', 'de', 'ko', 'az', 'af', 'lv', 'sl', 'si', 'pl', 'mk', 'hr', 'zh', 'fa', 'th', 'cs', 'ps', 'it', 'ja', 'my', 'ro', 'tl', 'uk', 'sv'}
#
# TYPO with mgpt -> 18 languages in common: {'ta', 'et', 'he', 'fi', 'ar', 'en', 'fa', 'it', 'ja', 'hi', 'ur', 'tl', 'sw', 'de', 'vi', 'az', 'th', 'bn'}
# TYPO with mgpt -> 3 languages not in model: {'mk', 'zh', 'nl'}
#
# LEARN with mt5 -> 18 languages in common: {'ta', 'fi', 'pt', 'lt', 'km', 'my', 'lv', 'hi', 'ja', 'sl', 'tr', 'ko', 'cs', 'id', 'vi', 'uk', 'nl', 'sv'}
# LEARN with mt5 -> 2 languages not in model: {'hr', 'tl'}
#
# LEARN with mgpt -> 15 languages in common: {'ta', 'fi', 'pt', 'lt', 'my', 'lv', 'hi', 'ja', 'tl', 'tr', 'ko', 'id', 'vi', 'uk', 'sv'}
# LEARN with mgpt -> 5 languages not in model: {'km', 'sl', 'cs', 'hr', 'nl'}
#
# GEO with mt5 -> 15 languages in common: {'af', 'ta', 'et', 'he', 'kk', 'gu', 'mn', 'ja', 'ka', 'ur', 'sw', 'fr', 'id', 'vi', 'bn'}
# GEO with mt5 -> 1 languages not in model: {'hr'}
#
# SEM with mt5 -> 15 languages in common: {'kk', 'ps', 'en', 'gu', 'gl', 'ka', 'sl', 'si', 'ml', 'pl', 'fr', 'ko', 'vi', 'uk', 'sv'}
# SEM with mt5 -> 1 languages not in model: {'tl'}
#
# GEO with mgpt -> 14 languages in common: {'af', 'ta', 'et', 'he', 'kk', 'mn', 'ja', 'ka', 'ur', 'sw', 'fr', 'id', 'vi', 'bn'}
# GEO with mgpt -> 2 languages not in model: {'hr', 'gu'}
#
# RND with bloom -> 13 languages in common: {'ta', 'ar', 'en', 'pt', 'gu', 'es', 'ne', 'mr', 'hi', 'ml', 'fr', 'id', 'vi'}
# RND with bloom -> 19 languages not in model: {'et', 'he', 'mn', 'ru', 'uk', 'de', 'ko', 'az', 'lv', 'si', 'pl', 'mk', 'zh', 'hr', 'ps', 'it', 'ja', 'cs', 'sv'}
#
# SEM with mgpt -> 11 languages in common: {'kk', 'en', 'ka', 'tl', 'ml', 'pl', 'fr', 'ko', 'vi', 'uk', 'sv'}
# SEM with mgpt -> 5 languages not in model: {'ps', 'gu', 'gl', 'sl', 'si'}
#
# FAM with bloom -> 8 languages in common: {'ta', 'xh', 'ar', 'en', 'ml', 'sw', 'id', 'vi'}
# FAM with bloom -> 14 languages not in model: {'af', 'et', 'he', 'fi', 'mn', 'my', 'ka', 'ja', 'tl', 'tr', 'ko', 'az', 'zh', 'th'}
#
# GEO with bloom -> 8 languages in common: {'ta', 'gu', 'ur', 'sw', 'fr', 'id', 'vi', 'bn'}
# GEO with bloom -> 8 languages not in model: {'af', 'et', 'he', 'kk', 'mn', 'ja', 'ka', 'hr'}
#
# TYPO with bloom -> 8 languages in common: {'ta', 'ar', 'en', 'hi', 'ur', 'sw', 'vi', 'bn'}
# TYPO with bloom -> 13 languages not in model: {'fa', 'et', 'fi', 'he', 'it', 'ja', 'tl', 'de', 'az', 'mk', 'zh', 'nl', 'th'}
#
# LEARN with bloom -> 5 languages in common: {'ta', 'pt', 'hi', 'id', 'vi'}
# LEARN with bloom -> 15 languages not in model: {'fi', 'lt', 'km', 'my', 'lv', 'ja', 'sl', 'tl', 'tr', 'ko', 'cs', 'uk', 'hr', 'nl', 'sv'}
#
# SEM with bloom -> 5 languages in common: {'en', 'gu', 'ml', 'fr', 'vi'}
# SEM with bloom -> 11 languages not in model: {'kk', 'ps', 'gl', 'ka', 'sl', 'si', 'tl', 'pl', 'ko', 'uk', 'sv'}

# %%
from collections import defaultdict


# Function to compute intersections of task, model, and subsets with sorting by full intersection
def compute_intersections_with_sorted_full(task_langs, model_langs, subsets):
    all_results = []

    # Iterate over all models and subset groups
    for model_name, model_langs_set in model_langs.items():
        model_langs_set = set(model_langs_set)

        for subset_group_name, subset_group in subsets.items():
            # Combine all subset languages in the group
            combined_subset_languages = set(chain.from_iterable(subset_group))

            # Calculate intersections
            task_model_intersection = task_langs.intersection(model_langs_set)
            subset_task_intersection = task_langs.intersection(combined_subset_languages)
            model_subset_intersection = model_langs_set.intersection(combined_subset_languages)
            full_intersection = task_langs.intersection(model_langs_set).intersection(combined_subset_languages)

            # Calculate the maximum possible intersections (minimum of two sets compared)
            max_task_model_intersection = min(len(task_langs), len(model_langs_set))
            max_subset_task_intersection = min(len(task_langs), len(combined_subset_languages))
            max_model_subset_intersection = min(len(model_langs_set), len(combined_subset_languages))
            max_full_intersection = min(len(task_langs), len(model_langs_set), len(combined_subset_languages))

            # Store results in a list
            all_results.append({
                'model': model_name,
                'subset_group': subset_group_name,
                'task_model_intersection': task_model_intersection,
                'subset_task_intersection': subset_task_intersection,
                'model_subset_intersection': model_subset_intersection,
                'full_intersection': full_intersection,
                'num_task_model_intersection': len(task_model_intersection),
                'num_subset_task_intersection': len(subset_task_intersection),
                'num_model_subset_intersection': len(model_subset_intersection),
                'num_full_intersection': len(full_intersection),
                'max_task_model_intersection': max_task_model_intersection,  # Corrected max value
                'max_subset_task_intersection': max_subset_task_intersection,  # Corrected max value
                'max_model_subset_intersection': max_model_subset_intersection,  # Corrected max value
                'max_full_intersection': max_full_intersection  # Corrected max value
            })

    # Sort the results by the number of full intersections in descending order
    sorted_results = sorted(all_results, key=lambda x: x['num_full_intersection'], reverse=True)

    return sorted_results


# Example for XCOPA
subset_groups = {
    'RND': [subsets['RND-1'], subsets['RND-2'], subsets['RND-3']],
    'FAM': [subsets['FAM-1'], subsets['FAM-2'], subsets['FAM-3']],
    'GEO': [subsets['GEO-1'], subsets['GEO-2'], subsets['GEO-3']],
    'LEARN': [subsets['LEARN-1'], subsets['LEARN-2'], subsets['LEARN-3']],
    'SEM': [subsets['SEM-1'], subsets['SEM-2'], subsets['SEM-3']],
    'TYPO': [subsets['TYPO-1'], subsets['TYPO-2'], subsets['TYPO-3']],
    'ALL': [subsets['ALL']]
}

# 'xnli', 'xcopa', 'xstorycloze', 'xwinograd', 'pawsx',
xnli_languages = set(task_languages['xnli'])
xcopa_languages = set(task_languages['xcopa'])
xstorycloze_languages = set(task_languages['xstorycloze'])
xwinograd_languages = set(task_languages['xwinograd'])
pawsx_languages = set(task_languages['pawsx'])
# Get the breakdown of intersections
xnli_breakdown_results_sorted_by_full = compute_intersections_with_sorted_full(xnli_languages, model_languages,
                                                                               subset_groups)
xcopa_breakdown_results_sorted_by_full = compute_intersections_with_sorted_full(xcopa_languages, model_languages,
                                                                                subset_groups)
xstorycloze_breakdown_results_sorted_by_full = compute_intersections_with_sorted_full(xstorycloze_languages,
                                                                                      model_languages,
                                                                                      subset_groups)
xwinograd_breakdown_results_sorted_by_full = compute_intersections_with_sorted_full(xwinograd_languages,
                                                                                    model_languages,
                                                                                    subset_groups)
pawsx_breakdown_results_sorted_by_full = compute_intersections_with_sorted_full(pawsx_languages, model_languages,
                                                                                subset_groups)


# Display the sorted results
def display_sorted_grouped_results(sorted_results):
    for result in sorted_results:
        print(
            f"{result['subset_group']} with {result['model']} -> {result['num_full_intersection']}/{result['max_full_intersection']} languages in common (Full Intersection): {result['full_intersection']}")
        print(
            f"  Task-Model Intersection: {result['num_task_model_intersection']}/{result['max_task_model_intersection']} languages")
        print(
            f"  Subset-Task Intersection: {result['num_subset_task_intersection']}/{result['max_subset_task_intersection']} languages")
        print(
            f"  Model-Subset Intersection: {result['num_model_subset_intersection']}/{result['max_model_subset_intersection']} languages")
        print()  # For better readability


# Example of how to use the function
print('------ XNLI -------')
display_sorted_grouped_results(xnli_breakdown_results_sorted_by_full)
print('------ XCOPA -------')
display_sorted_grouped_results(xcopa_breakdown_results_sorted_by_full)
print('------ XSTORYCLOZE -------')
display_sorted_grouped_results(xstorycloze_breakdown_results_sorted_by_full)
print('------ XWINOGRAD -------')
display_sorted_grouped_results(xwinograd_breakdown_results_sorted_by_full)
print('------ PAWSX -------')
display_sorted_grouped_results(pawsx_breakdown_results_sorted_by_full)
# Out:
# ------ XNLI -------
# ALL with mt5 -> 13/15 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'ur', 'sw', 'tr', 'de', 'fr', 'ru', 'vi', 'zh', 'th'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 13/15 languages
#   Model-Subset Intersection: 50/52 languages
#
# ALL with mgpt -> 12/15 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'ur', 'sw', 'tr', 'de', 'fr', 'ru', 'vi', 'th'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 13/15 languages
#   Model-Subset Intersection: 39/52 languages
#
# RND with mt5 -> 9/15 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'fr', 'de', 'ru', 'vi', 'zh'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 9/15 languages
#   Model-Subset Intersection: 31/32 languages
#
# TYPO with mt5 -> 9/15 languages in common (Full Intersection): {'ar', 'en', 'hi', 'ur', 'sw', 'de', 'vi', 'zh', 'th'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 9/15 languages
#   Model-Subset Intersection: 20/21 languages
#
# ALL with bloom -> 8/15 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'ur', 'sw', 'fr', 'vi'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 13/15 languages
#   Model-Subset Intersection: 18/46 languages
#
# RND with mgpt -> 8/15 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'fr', 'de', 'ru', 'vi'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 9/15 languages
#   Model-Subset Intersection: 24/32 languages
#
# TYPO with mgpt -> 8/15 languages in common (Full Intersection): {'ar', 'en', 'hi', 'ur', 'sw', 'de', 'vi', 'th'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 9/15 languages
#   Model-Subset Intersection: 18/21 languages
#
# FAM with mt5 -> 7/15 languages in common (Full Intersection): {'ar', 'en', 'sw', 'tr', 'vi', 'zh', 'th'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 7/15 languages
#   Model-Subset Intersection: 21/22 languages
#
# RND with bloom -> 6/15 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'fr', 'vi'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 9/15 languages
#   Model-Subset Intersection: 13/32 languages
#
# TYPO with bloom -> 6/15 languages in common (Full Intersection): {'ar', 'en', 'hi', 'ur', 'sw', 'vi'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 9/15 languages
#   Model-Subset Intersection: 8/21 languages
#
# FAM with mgpt -> 6/15 languages in common (Full Intersection): {'ar', 'en', 'sw', 'tr', 'vi', 'th'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 7/15 languages
#   Model-Subset Intersection: 20/22 languages
#
# FAM with bloom -> 4/15 languages in common (Full Intersection): {'sw', 'ar', 'vi', 'en'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 7/15 languages
#   Model-Subset Intersection: 8/22 languages
#
# GEO with bloom -> 4/15 languages in common (Full Intersection): {'sw', 'fr', 'vi', 'ur'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 4/15 languages
#   Model-Subset Intersection: 8/16 languages
#
# GEO with mgpt -> 4/15 languages in common (Full Intersection): {'sw', 'fr', 'vi', 'ur'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 4/15 languages
#   Model-Subset Intersection: 14/16 languages
#
# GEO with mt5 -> 4/15 languages in common (Full Intersection): {'sw', 'fr', 'vi', 'ur'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 4/15 languages
#   Model-Subset Intersection: 15/16 languages
#
# SEM with bloom -> 3/15 languages in common (Full Intersection): {'fr', 'vi', 'en'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 3/15 languages
#   Model-Subset Intersection: 5/16 languages
#
# LEARN with mgpt -> 3/15 languages in common (Full Intersection): {'tr', 'hi', 'vi'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 3/15 languages
#   Model-Subset Intersection: 15/20 languages
#
# SEM with mgpt -> 3/15 languages in common (Full Intersection): {'fr', 'vi', 'en'}
#   Task-Model Intersection: 14/15 languages
#   Subset-Task Intersection: 3/15 languages
#   Model-Subset Intersection: 11/16 languages
#
# LEARN with mt5 -> 3/15 languages in common (Full Intersection): {'tr', 'hi', 'vi'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 3/15 languages
#   Model-Subset Intersection: 18/20 languages
#
# SEM with mt5 -> 3/15 languages in common (Full Intersection): {'fr', 'vi', 'en'}
#   Task-Model Intersection: 15/15 languages
#   Subset-Task Intersection: 3/15 languages
#   Model-Subset Intersection: 15/16 languages
#
# LEARN with bloom -> 2/15 languages in common (Full Intersection): {'hi', 'vi'}
#   Task-Model Intersection: 8/15 languages
#   Subset-Task Intersection: 3/15 languages
#   Model-Subset Intersection: 5/20 languages
#
# ------ XCOPA -------
# ALL with mt5 -> 9/11 languages in common (Full Intersection): {'ta', 'et', 'it', 'tr', 'sw', 'id', 'vi', 'zh', 'th'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 9/11 languages
#   Model-Subset Intersection: 50/52 languages
#
# ALL with mgpt -> 8/11 languages in common (Full Intersection): {'ta', 'et', 'it', 'tr', 'sw', 'id', 'vi', 'th'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 9/11 languages
#   Model-Subset Intersection: 39/52 languages
#
# FAM with mt5 -> 8/11 languages in common (Full Intersection): {'ta', 'et', 'tr', 'sw', 'id', 'vi', 'zh', 'th'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 8/11 languages
#   Model-Subset Intersection: 21/22 languages
#
# FAM with mgpt -> 7/11 languages in common (Full Intersection): {'ta', 'et', 'tr', 'sw', 'id', 'vi', 'th'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 8/11 languages
#   Model-Subset Intersection: 20/22 languages
#
# TYPO with mt5 -> 7/11 languages in common (Full Intersection): {'ta', 'et', 'it', 'sw', 'vi', 'zh', 'th'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 7/11 languages
#   Model-Subset Intersection: 20/21 languages
#
# TYPO with mgpt -> 6/11 languages in common (Full Intersection): {'ta', 'et', 'it', 'sw', 'vi', 'th'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 7/11 languages
#   Model-Subset Intersection: 18/21 languages
#
# RND with mt5 -> 6/11 languages in common (Full Intersection): {'ta', 'et', 'it', 'id', 'vi', 'zh'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 6/11 languages
#   Model-Subset Intersection: 31/32 languages
#
# RND with mgpt -> 5/11 languages in common (Full Intersection): {'ta', 'et', 'it', 'id', 'vi'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 6/11 languages
#   Model-Subset Intersection: 24/32 languages
#
# GEO with mgpt -> 5/11 languages in common (Full Intersection): {'ta', 'et', 'sw', 'id', 'vi'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 5/11 languages
#   Model-Subset Intersection: 14/16 languages
#
# GEO with mt5 -> 5/11 languages in common (Full Intersection): {'ta', 'et', 'sw', 'id', 'vi'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 5/11 languages
#   Model-Subset Intersection: 15/16 languages
#
# FAM with bloom -> 4/11 languages in common (Full Intersection): {'sw', 'ta', 'id', 'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 8/11 languages
#   Model-Subset Intersection: 8/22 languages
#
# GEO with bloom -> 4/11 languages in common (Full Intersection): {'sw', 'ta', 'id', 'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 5/11 languages
#   Model-Subset Intersection: 8/16 languages
#
# ALL with bloom -> 4/11 languages in common (Full Intersection): {'sw', 'ta', 'id', 'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 9/11 languages
#   Model-Subset Intersection: 18/46 languages
#
# LEARN with mgpt -> 4/11 languages in common (Full Intersection): {'tr', 'ta', 'id', 'vi'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 4/11 languages
#   Model-Subset Intersection: 15/20 languages
#
# LEARN with mt5 -> 4/11 languages in common (Full Intersection): {'tr', 'ta', 'id', 'vi'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 4/11 languages
#   Model-Subset Intersection: 18/20 languages
#
# RND with bloom -> 3/11 languages in common (Full Intersection): {'ta', 'id', 'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 6/11 languages
#   Model-Subset Intersection: 13/32 languages
#
# LEARN with bloom -> 3/11 languages in common (Full Intersection): {'ta', 'id', 'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 4/11 languages
#   Model-Subset Intersection: 5/20 languages
#
# TYPO with bloom -> 3/11 languages in common (Full Intersection): {'sw', 'ta', 'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 7/11 languages
#   Model-Subset Intersection: 8/21 languages
#
# SEM with bloom -> 1/11 languages in common (Full Intersection): {'vi'}
#   Task-Model Intersection: 4/11 languages
#   Subset-Task Intersection: 1/11 languages
#   Model-Subset Intersection: 5/16 languages
#
# SEM with mgpt -> 1/11 languages in common (Full Intersection): {'vi'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 1/11 languages
#   Model-Subset Intersection: 11/16 languages
#
# SEM with mt5 -> 1/11 languages in common (Full Intersection): {'vi'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 1/11 languages
#   Model-Subset Intersection: 15/16 languages
#
# ------ XSTORYCLOZE -------
# ALL with mt5 -> 10/11 languages in common (Full Intersection): {'ar', 'en', 'es', 'te', 'my', 'hi', 'sw', 'id', 'ru', 'zh'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 10/11 languages
#   Model-Subset Intersection: 50/52 languages
#
# ALL with mgpt -> 9/11 languages in common (Full Intersection): {'ar', 'en', 'es', 'te', 'my', 'hi', 'sw', 'id', 'ru'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 10/11 languages
#   Model-Subset Intersection: 39/52 languages
#
# ALL with bloom -> 7/11 languages in common (Full Intersection): {'ar', 'en', 'es', 'te', 'hi', 'sw', 'id'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 10/11 languages
#   Model-Subset Intersection: 18/46 languages
#
# RND with mt5 -> 7/11 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'id', 'ru', 'zh'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 7/11 languages
#   Model-Subset Intersection: 31/32 languages
#
# RND with mgpt -> 6/11 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'id', 'ru'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 7/11 languages
#   Model-Subset Intersection: 24/32 languages
#
# FAM with mt5 -> 6/11 languages in common (Full Intersection): {'ar', 'en', 'my', 'sw', 'id', 'zh'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 6/11 languages
#   Model-Subset Intersection: 21/22 languages
#
# RND with bloom -> 5/11 languages in common (Full Intersection): {'ar', 'en', 'es', 'hi', 'id'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 7/11 languages
#   Model-Subset Intersection: 13/32 languages
#
# FAM with mgpt -> 5/11 languages in common (Full Intersection): {'ar', 'en', 'my', 'sw', 'id'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 6/11 languages
#   Model-Subset Intersection: 20/22 languages
#
# TYPO with mt5 -> 5/11 languages in common (Full Intersection): {'ar', 'en', 'hi', 'sw', 'zh'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 5/11 languages
#   Model-Subset Intersection: 20/21 languages
#
# FAM with bloom -> 4/11 languages in common (Full Intersection): {'sw', 'id', 'ar', 'en'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 6/11 languages
#   Model-Subset Intersection: 8/22 languages
#
# TYPO with bloom -> 4/11 languages in common (Full Intersection): {'sw', 'ar', 'hi', 'en'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 5/11 languages
#   Model-Subset Intersection: 8/21 languages
#
# TYPO with mgpt -> 4/11 languages in common (Full Intersection): {'sw', 'ar', 'hi', 'en'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 5/11 languages
#   Model-Subset Intersection: 18/21 languages
#
# LEARN with mgpt -> 3/11 languages in common (Full Intersection): {'id', 'my', 'hi'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 3/11 languages
#   Model-Subset Intersection: 15/20 languages
#
# LEARN with mt5 -> 3/11 languages in common (Full Intersection): {'id', 'my', 'hi'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 3/11 languages
#   Model-Subset Intersection: 18/20 languages
#
# GEO with bloom -> 2/11 languages in common (Full Intersection): {'sw', 'id'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 2/11 languages
#   Model-Subset Intersection: 8/16 languages
#
# LEARN with bloom -> 2/11 languages in common (Full Intersection): {'id', 'hi'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 3/11 languages
#   Model-Subset Intersection: 5/20 languages
#
# GEO with mgpt -> 2/11 languages in common (Full Intersection): {'sw', 'id'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 2/11 languages
#   Model-Subset Intersection: 14/16 languages
#
# GEO with mt5 -> 2/11 languages in common (Full Intersection): {'sw', 'id'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 2/11 languages
#   Model-Subset Intersection: 15/16 languages
#
# SEM with bloom -> 1/11 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 8/11 languages
#   Subset-Task Intersection: 1/11 languages
#   Model-Subset Intersection: 5/16 languages
#
# SEM with mgpt -> 1/11 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 10/11 languages
#   Subset-Task Intersection: 1/11 languages
#   Model-Subset Intersection: 11/16 languages
#
# SEM with mt5 -> 1/11 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 11/11 languages
#   Subset-Task Intersection: 1/11 languages
#   Model-Subset Intersection: 15/16 languages
#
# ------ XWINOGRAD -------
# RND with mt5 -> 6/6 languages in common (Full Intersection): {'en', 'pt', 'ja', 'fr', 'ru', 'zh'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 6/6 languages
#   Model-Subset Intersection: 31/32 languages
#
# ALL with mt5 -> 6/6 languages in common (Full Intersection): {'en', 'pt', 'ja', 'fr', 'ru', 'zh'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 6/6 languages
#   Model-Subset Intersection: 50/52 languages
#
# RND with mgpt -> 5/6 languages in common (Full Intersection): {'en', 'pt', 'ja', 'fr', 'ru'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 6/6 languages
#   Model-Subset Intersection: 24/32 languages
#
# ALL with mgpt -> 5/6 languages in common (Full Intersection): {'en', 'pt', 'ja', 'fr', 'ru'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 6/6 languages
#   Model-Subset Intersection: 39/52 languages
#
# RND with bloom -> 3/6 languages in common (Full Intersection): {'fr', 'en', 'pt'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 6/6 languages
#   Model-Subset Intersection: 13/32 languages
#
# ALL with bloom -> 3/6 languages in common (Full Intersection): {'fr', 'en', 'pt'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 6/6 languages
#   Model-Subset Intersection: 18/46 languages
#
# FAM with mt5 -> 3/6 languages in common (Full Intersection): {'ja', 'zh', 'en'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 3/6 languages
#   Model-Subset Intersection: 21/22 languages
#
# TYPO with mt5 -> 3/6 languages in common (Full Intersection): {'ja', 'zh', 'en'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 3/6 languages
#   Model-Subset Intersection: 20/21 languages
#
# SEM with bloom -> 2/6 languages in common (Full Intersection): {'fr', 'en'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 5/16 languages
#
# FAM with mgpt -> 2/6 languages in common (Full Intersection): {'ja', 'en'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 3/6 languages
#   Model-Subset Intersection: 20/22 languages
#
# GEO with mgpt -> 2/6 languages in common (Full Intersection): {'fr', 'ja'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 14/16 languages
#
# LEARN with mgpt -> 2/6 languages in common (Full Intersection): {'ja', 'pt'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 15/20 languages
#
# SEM with mgpt -> 2/6 languages in common (Full Intersection): {'fr', 'en'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 11/16 languages
#
# TYPO with mgpt -> 2/6 languages in common (Full Intersection): {'ja', 'en'}
#   Task-Model Intersection: 5/6 languages
#   Subset-Task Intersection: 3/6 languages
#   Model-Subset Intersection: 18/21 languages
#
# GEO with mt5 -> 2/6 languages in common (Full Intersection): {'fr', 'ja'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 15/16 languages
#
# LEARN with mt5 -> 2/6 languages in common (Full Intersection): {'ja', 'pt'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 18/20 languages
#
# SEM with mt5 -> 2/6 languages in common (Full Intersection): {'fr', 'en'}
#   Task-Model Intersection: 6/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 15/16 languages
#
# FAM with bloom -> 1/6 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 3/6 languages
#   Model-Subset Intersection: 8/22 languages
#
# GEO with bloom -> 1/6 languages in common (Full Intersection): {'fr'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 8/16 languages
#
# LEARN with bloom -> 1/6 languages in common (Full Intersection): {'pt'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 2/6 languages
#   Model-Subset Intersection: 5/20 languages
#
# TYPO with bloom -> 1/6 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 3/6 languages
#   Subset-Task Intersection: 3/6 languages
#   Model-Subset Intersection: 8/21 languages
#
# ------ PAWSX -------
# RND with mt5 -> 7/7 languages in common (Full Intersection): {'en', 'es', 'ja', 'fr', 'de', 'ko', 'zh'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 7/7 languages
#   Model-Subset Intersection: 31/32 languages
#
# ALL with mt5 -> 7/7 languages in common (Full Intersection): {'en', 'es', 'ja', 'fr', 'de', 'ko', 'zh'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 7/7 languages
#   Model-Subset Intersection: 50/52 languages
#
# RND with mgpt -> 6/7 languages in common (Full Intersection): {'en', 'es', 'ja', 'fr', 'de', 'ko'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 7/7 languages
#   Model-Subset Intersection: 24/32 languages
#
# ALL with mgpt -> 6/7 languages in common (Full Intersection): {'en', 'es', 'ja', 'fr', 'de', 'ko'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 7/7 languages
#   Model-Subset Intersection: 39/52 languages
#
# FAM with mt5 -> 4/7 languages in common (Full Intersection): {'ja', 'ko', 'zh', 'en'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 4/7 languages
#   Model-Subset Intersection: 21/22 languages
#
# TYPO with mt5 -> 4/7 languages in common (Full Intersection): {'de', 'ja', 'zh', 'en'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 4/7 languages
#   Model-Subset Intersection: 20/21 languages
#
# RND with bloom -> 3/7 languages in common (Full Intersection): {'es', 'fr', 'en'}
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 7/7 languages
#   Model-Subset Intersection: 13/32 languages
#
# ALL with bloom -> 3/7 languages in common (Full Intersection): {'es', 'fr', 'en'}
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 7/7 languages
#   Model-Subset Intersection: 18/46 languages
#
# FAM with mgpt -> 3/7 languages in common (Full Intersection): {'ja', 'ko', 'en'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 4/7 languages
#   Model-Subset Intersection: 20/22 languages
#
# SEM with mgpt -> 3/7 languages in common (Full Intersection): {'fr', 'ko', 'en'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 3/7 languages
#   Model-Subset Intersection: 11/16 languages
#
# TYPO with mgpt -> 3/7 languages in common (Full Intersection): {'de', 'ja', 'en'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 4/7 languages
#   Model-Subset Intersection: 18/21 languages
#
# SEM with mt5 -> 3/7 languages in common (Full Intersection): {'fr', 'ko', 'en'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 3/7 languages
#   Model-Subset Intersection: 15/16 languages
#
# SEM with bloom -> 2/7 languages in common (Full Intersection): {'fr', 'en'}
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 3/7 languages
#   Model-Subset Intersection: 5/16 languages
#
# GEO with mgpt -> 2/7 languages in common (Full Intersection): {'fr', 'ja'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 2/7 languages
#   Model-Subset Intersection: 14/16 languages
#
# LEARN with mgpt -> 2/7 languages in common (Full Intersection): {'ja', 'ko'}
#   Task-Model Intersection: 6/7 languages
#   Subset-Task Intersection: 2/7 languages
#   Model-Subset Intersection: 15/20 languages
#
# GEO with mt5 -> 2/7 languages in common (Full Intersection): {'fr', 'ja'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 2/7 languages
#   Model-Subset Intersection: 15/16 languages
#
# LEARN with mt5 -> 2/7 languages in common (Full Intersection): {'ja', 'ko'}
#   Task-Model Intersection: 7/7 languages
#   Subset-Task Intersection: 2/7 languages
#   Model-Subset Intersection: 18/20 languages
#
# FAM with bloom -> 1/7 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 4/7 languages
#   Model-Subset Intersection: 8/22 languages
#
# GEO with bloom -> 1/7 languages in common (Full Intersection): {'fr'}
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 2/7 languages
#   Model-Subset Intersection: 8/16 languages
#
# TYPO with bloom -> 1/7 languages in common (Full Intersection): {'en'}
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 4/7 languages
#   Model-Subset Intersection: 8/21 languages
#
# LEARN with bloom -> 0/7 languages in common (Full Intersection): set()
#   Task-Model Intersection: 3/7 languages
#   Subset-Task Intersection: 2/7 languages
#   Model-Subset Intersection: 5/20 languages
